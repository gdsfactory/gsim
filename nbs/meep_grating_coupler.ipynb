# %% [markdown]
# # Grating Coupler Simulation with FiberSource
#
# [MEEP](https://meep.readthedocs.io/) is an open-source FDTD electromagnetic simulator. This notebook demonstrates using the `gsim.meep` **FiberSource** API to simulate fiber-to-chip coupling through a grating coupler.
#
# Unlike S-parameter simulations that use eigenmode sources at waveguide ports, grating coupler simulations launch a **Gaussian beam from above** (simulating a fiber) and measure the power coupled into the waveguide port via eigenmode decomposition.
#
# **Requirements:**
#
# - UBC PDK: `uv pip install ubcpdk`
# - [GDSFactory+](https://gdsfactory.com) account for cloud simulation

# %% [markdown]
# ### Load a grating coupler from UBC PDK

# %%
from ubcpdk import PDK, cells

PDK.activate()

c = cells.ebeam_gc_te1550()
c

# %% [markdown]
# ### Configure simulation with FiberSource
#
# Instead of `ModeSource` (which excites a waveguide eigenmode at a port), we use `FiberSource` to launch a Gaussian beam from above the grating. Key parameters:
#
# - **beam_waist**: Gaussian beam waist radius (SMF-28 mode field diameter / 2 = 5.2 um)
# - **angle_theta**: Fiber tilt angle from vertical (typically 8-15 degrees for grating couplers)
# - **z_offset**: Distance above the chip surface to place the source plane
# - **polarization**: TE or TM
#
# The result is a `CouplingResult` instead of `SParameterResult`, giving coupling efficiency (CE) per port.

# %%
from gsim import meep

sim = meep.Simulation()

sim.geometry(component=c, z_crop="auto")
sim.materials = {"si": 3.47, "SiO2": 1.44}

sim.source = meep.FiberSource(
    wavelength=1.55,
    wavelength_span=0.07,
    num_freqs=21,
    beam_waist=5.2,
    angle_theta=10.0,
    z_offset=2.0,
    position=[-25, 0],
)

sim.monitors = ["o1"]
sim.domain(pml=1.0, margin=1.0, margin_z_above=3.0)
sim.solver(resolution=25, save_animation=True, verbose_interval=5.0)
sim.solver.stop_after_sources(time=110)
sim.solver.animation_plane = "xz"

print(sim.validate_config())
# Out:
# Stack validation: PASSED
# Warnings:
#   - No stack configured. Will use active PDK with defaults.
#   - Stopping: fixed (time=110.0)

# %% [markdown]
# ### Preview geometry

# %%
sim.plot_2d(slices="xyz")
# Out:
# /Users/vahid/doplaydo/gsim/src/gsim/meep/simulation.py:576: UserWarning: Material 'Aluminum' has no optical properties (refractive_index) — layer will be omitted from simulation. Use sim.set_material('Aluminum', refractive_index=...) to include it.
#   material_data = resolve_materials(
# /Users/vahid/doplaydo/gsim/src/gsim/meep/simulation.py:576: UserWarning: Material 'TiN' has no optical properties (refractive_index) — layer will be omitted from simulation. Use sim.set_material('TiN', refractive_index=...) to include it.
#   material_data = resolve_materials(
# /Users/vahid/doplaydo/gsim/src/gsim/meep/simulation.py:576: UserWarning: Material 'passive' has no optical properties (refractive_index) — layer will be omitted from simulation. Use sim.set_material('passive', refractive_index=...) to include it.
#   material_data = resolve_materials(

# %% [markdown]
# ### Run simulation on cloud

# %%
result = sim.run()
# Out:
#   meep-8abb470b  running  10m 49s
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result = sim.run()
#
# File ~/doplaydo/gsim/src/gsim/meep/simulation.py:777, in Simulation.run(self, parent_dir, verbose, wait)
#     775 if not wait:
#     776     return self._job_id
# --> 777 return self.wait_for_results(verbose=verbose, parent_dir=parent_dir)
#
# File ~/doplaydo/gsim/src/gsim/meep/simulation.py:744, in Simulation.wait_for_results(self, verbose, parent_dir)
#     742 if self._job_id is None:
#     743     raise ValueError("No job submitted yet")
# --> 744 return gcloud.wait_for_results(
#     745     self._job_id, verbose=verbose, parent_dir=parent_dir
#     746 )
#
# File ~/doplaydo/gsim/src/gsim/gcloud.py:430, in wait_for_results(verbose, parent_dir, poll_interval, *job_ids)
#     428 for jid, job in jobs.items():
#     429     if job.status not in terminal:
# --> 430         jobs[jid] = sim.get_job(jid)
#     431         # Stream logs when running
#     432         if verbose == "full" and jobs[jid].status == sim.SimStatus.RUNNING:
#
# File ~/doplaydo/gsim/.venv/lib/python3.12/site-packages/gdsfactoryplus/sim.py:303, in get_job(job_id)
#     298 with httpx.Client(timeout=TIMEOUT) as client:
#     299     response = client.get(
#     300         f"{_base_url()}/job/{job_id}",
#     301         headers=_headers(),
#     302     )
# --> 303     response.raise_for_status()
#     304     data = response.json()
#     305 job = Job.model_validate(data["data"])
#
# File ~/doplaydo/gsim/.venv/lib/python3.12/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     827 error_type = error_types.get(status_class, "Invalid status code")
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Server error '503 Service Unavailable' for url 'https://api.gdsfactory.com/api/simulation/sdk/v1/job/019d6bff-3478-7a42-9818-cd3a3c393cf4'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/503

# %% [markdown]
# ### Plot coupling efficiency

# %%
result.plot(db=True)

# %%
print("Peak coupling efficiency (dB):")
for port, ce_db in result.peak_ce.items():
    print(f"  {port}: {ce_db:.2f} dB")
# Out:
# Peak coupling efficiency (dB):
#   o1: -37.33 dB

# %%
result.show_animation()
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
