# %% [markdown]
# # FDTD Meep Grating Coupler
#
# [MEEP](https://meep.readthedocs.io/) is an open-source FDTD electromagnetic simulator. This notebook demonstrates using the `gsim.meep` API to run an S-parameter simulation on a grating coupler.
#
# **Requirements:**
#
# - [GDSFactory+](https://gdsfactory.com) account for cloud simulation
#
# ```
#                 fiber_xposition
#                      |
#                 fiber_core_diameter
#              /     /  /     /       |
#             /     /  /     /        | fiber_thickness
#            /     /  /     /    _ _ _| _ _ _ _ _ _  _
#                                     |
#                                     | air_gap_thickness
#                                _ _ _| _ _ _ _ _ _  _
#                                     |
#                    clad_material    | top_clad_thickness
#                                _ _ _| _ _ _ _ _ _  _
#                 _|-|_|-|_|-|___     |              _| etch_depth
#                core_material        |     |core_thickness
#                 ______________|_ _ _|_ _ _ _ _ _ _ _
#                                     |
#                  nbox               |box_thickness
#                 ______________ _ _ _|_ _ _ _ _ _ _ _
#                                     |
#                  nsubstrate         |substrate_thickness
#                 ______________ _ _ _|
# ```

# %% [markdown]
# ### Load a grating coupler from gdsfactory generic PDK

# %%
import gdsfactory as gf

gf.gpdk.PDK.activate()

c = gf.components.grating_coupler_elliptical()
c

# %% [markdown]
# ### Configure and run simulation

# %%
from gsim import meep

sim = meep.Simulation()

sim.geometry(component=c, z_crop="auto")
sim.materials = {"si": 3.47, "SiO2": 1.44}
sim.source(port="o1", wavelength=1.55, wavelength_span=0.04, num_freqs=51)
sim.monitors = ["o1", "o2"]
sim.port_overrides = {"o2": {"width": 20}}
sim.domain(pml=1.0, margin=0.5)
sim.solver(
    resolution=20, simulation_plane="xz", save_animation=True, verbose_interval=5.0
)
sim.solver.stop_when_energy_decayed()

print(sim.validate_config())

# %%
sim.plot_2d(slices="y")

# %%
sim.plot_2d_interactive()

# %% [markdown]
# ### Run simulation on cloud

# %%
# Run on GDSFactory+ cloud
result = sim.run()

# %%
result.plot_interactive()

# %%
result.plot_interactive(phase=True)

# %%
result.show_animation()

# %% [markdown]
# ### Sweep grating parameters
#
# You can sweep grating coupler parameters by creating different components.

# %%
c2 = gf.components.grating_coupler_elliptical(grating_line_width=0.25)

sim2 = meep.Simulation()

sim2.geometry(component=c2, z_crop="auto")
sim2.materials = {"si": 3.47, "SiO2": 1.44}
sim2.source(port="o1", wavelength=1.55, wavelength_span=0.04, num_freqs=51)
sim2.monitors = ["o1", "o2"]
sim2.domain(pml=1.0, margin=0.5)
sim2.solver(
    resolution=20, simulation_plane="xz", save_animation=True, verbose_interval=5.0
)
sim2.solver.stop_when_energy_decayed()

print(sim2.validate_config())

# %%
sim2.plot_2d(slices="y")

# %%
sim2.plot_2d_interactive()

# %%
result2 = sim2.run()

# %%
result2.plot_interactive()
